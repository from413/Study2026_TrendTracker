# %%
# animals = ["앵무새", "원숭이", "갈매기"]# list
# animals.append("살쾡이") # +
# animals.insert(1, "다람쥐") # +
# animals.remove(animals[0]) # -
# animals.sort #정렬
# print(animals)
# animals.reverse() #역순
# print(animals)
# print(animals.count("원숭이"))
# print(animals.index("원숭이"))
# print(f"최종 리스트: {animals}, 길이: {len(animals)}")
# print(f"'사자'가 포함되어 있는지: {'사자' in animals}")
# Out:
# ['다람쥐', '원숭이', '갈매기', '살쾡이']
# ['살쾡이', '갈매기', '원숭이', '다람쥐']
# 1
# 2
# 최종 리스트: ['살쾡이', '갈매기', '원숭이', '다람쥐'], 길이: 4
# '사자'가 포함되어 있는지: False

# %%
# # 튜플 활용과 리스트 중복 제거
# # - 좌표 표현
# # - 리스트 중복 제거
# # Tuple

# # 좌표 만들기 (transform)
# A = (1, 2)
# B = (4, 6)
# C = (7, 3)

# # 할당
# ax, ay = A
# bx, by = B
# cx, cy = C

# # 좌표 평균 위치
# avg_x = (ax + bx + cx) / 3
# avg_y = (ay + by + cy) / 3
# print(f"{avg_x}\n{avg_y}")

# # 리스트 중복 제거
# numbers_memory = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
# unique_sorted= sorted(set(numbers_memory))
# print(f"중복 제거 + 정렬: {unique_sorted}")
# Out:
# 4.0
# 3.6666666666666665
# 중복 제거 + 정렬: [1, 2, 3, 4, 5, 6, 9]

# %%
# eng_dictionary = {
#     "watermelon": "수박",
#     "melon": "멜론",
#     "apple": "사과"
# }

# %%
# book_1 = {
#     "title": "Python Programming",
#     "author": "John Doe",
#     "year": 2021,
#     "price": 29.99
# }

# book_1["출판사"] = "Tech Press"
# book_1["pages"] = 300
# book_1["weight"] = 1.5
# del book_1["weight"]
# print(book_1)

# %%
# score = {
#     "국어": 90,
#     "영어": 80,
#     "수학": 70,
#     "과학": 60
# }

# for subject, score in score.items():
#     print(subject, score)

# for subject in score.keys():
#     print(subject)

# for score in score.values():
#     print(score)

# %%
phonebook_memory = {
    "kim": "010-3456-7890",
    "Eddard": "010-1234-5678",
    "randolph": "010-5678-1234"
}
phonebook_memory["amy"] = "010-4321-6543"
phonebook_memory["kim"] = "010-1234-5678"
user_key = "kim"
get_usermemory = phonebook_memory.get(user_key)
print(f"{user_key}의 전화번호는 {get_usermemory} 입니다")
# Out:
# kim의 전화번호는 010-1234-5678 입니다

# %%
# # ========================
# # 바구니에 물품 담기
# # ========================
# # 1 Mart ========================
# items = ["apple", "banana", "orange"] # 품목
# # [이름, 0] 형태로 구성된 2차원 리스트 생성
# cart_matrix = [[item, 0] for item in items] # 요구 Cart 개수
# print(cart_matrix) 

# cart_matrix[0][1] = 5 
# print(cart_matrix)

# target = "banana" # 선택된 items index
# for item in cart_matrix:
#     if item[0] == target:
#         item[1] += 1  # 바나나 개수 1 증가

# print(cart_matrix)

# # 2 Cafe ========================
# items_2 = ["Americano", "CafeLatte", "Smoothie"]
# cart_2_matrix = [[item_2, 0] for item_2 in items_2]
# print(cart_2_matrix)

# target_2 = "Smoothie"
# for item_2 in cart_2_matrix:
#     if item_2[0] == target_2:
#         item_2[1] += 1

# print(cart_2_matrix)
