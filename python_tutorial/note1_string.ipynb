# %%
print(3)
# Out:
# 3

# %%
from threading import local
from os import times_result

# ========================
# 간단한 명함
# ========================
name = "SungHyeonPark"
age = 35
height = 171
is_sit = False
print (name, age, height, sep="\n")
print ("")

# ========================
# boolean = True/False, On/Off , Close/Open
# ========================
if is_sit:
    print ("앉아 있나요?", is_sit)
elif not is_sit:
    is_sit = False
    print ("일어서 있나요?", is_sit)
print ("is_sit 타입은?", type(is_sit))
print ("")

# ========================
# 재고 관리를 시작해 봅시다
# ========================
# 1 Mart ========================
wheel = 3
tire = 5
print(f"조립 가능한 세트: {min(wheel, tire)}개")
# 두 값의 차이 (절대값)
print(f"남는 부품: {abs(wheel - tire)}개\n")

# 2 Cafe ========================
cup = 5
coffee = 7
print(f"제조할 수 있는 음료수: {min(cup, coffee)}개")
print(f"남는 소재: {abs(coffee - cup)}개\n")

# ========================
# 바구니에 물품 담기
# ========================
# 1 Mart ========================
items = ["apple", "banana", "orange"] # 품목
# [이름, 0] 형태로 구성된 2차원 리스트 생성
cart_matrix = [[item, 0] for item in items] # 요구 Cart 개수
print(cart_matrix) 

cart_matrix[0][1] = 5 
print(cart_matrix)

target = "banana" # 선택된 items index
for item in cart_matrix:
    if item[0] == target:
        item[1] += 1  # 바나나 개수 1 증가

print(cart_matrix)

# 2 Cafe ========================
items_2 = ["Americano", "CafeLatte", "Smoothie"]
cart_2_matrix = [[item_2, 0] for item_2 in items_2]
print(cart_2_matrix)

target_2 = "Smoothie"
for item_2 in cart_2_matrix:
    if item_2[0] == target_2:
        item_2[1] += 1

print(cart_2_matrix)
# ========================
# Database: 특정 index번호에 해당하는 문자로 시작하는 파일 찾기
# ========================
filename = "report_2024.xlsx"
filename.endswith(".xlsx")

filename = "2025_Report_Succes.pdf"
first_char = filename[0] # 첫번째 문자
last_char = filename[-1] # 마지막 문자
print(f"첫 글자: {first_char}, 끝 글자: {last_char}\n")

year_2 = filename[0:4]
extension = filename[-4:]

# [슬라이싱] - 범위 추출 [시작:끝+1]
year = filename[0:4]         # '2025'
extension = filename[-3:]    # 'pdf' (뒤에서 3번째부터 끝까지)
pure_name = filename[5:11]   # 'Report'
print(f"연도: {year}, 확장자: {extension}, 이름: {pure_name}")

# Cafe 재고 관리 데이터를 활용한 f-string
user_name = "SungHyeon"
order_item = "Americano"
count = 3
price = 4500

# 변수 직접 대입 및 연산
print(f"안녕하세요, {user_name}님!")
print(f"주문하신 {order_item} {count}잔의 총 금액은 {price * count}원입니다.")

# 소수점 및 형식 지정
pi = 3.141592
print(f"원주율 수치: {pi:.2f}") # 소수점 둘째 자리까지 표시

year = 2026
print("===== 개인 정보 =====")
print(f"이름: {name}\n나이: {age}\n태어난 해: {year-age+1}")
print("====================")
# Out:
# SungHyeonPark
# 35
# 171
#
# 일어서 있나요? False
# is_sit 타입은? <class 'bool'>
#
# 조립 가능한 세트: 3개
# 남는 부품: 2개
#
# 제조할 수 있는 음료수: 5개
# 남는 소재: 2개
#
# [['apple', 0], ['banana', 0], ['orange', 0]]
# [['apple', 5], ['banana', 0], ['orange', 0]]
# [['apple', 5], ['banana', 1], ['orange', 0]]
# [['Americano', 0], ['CafeLatte', 0], ['Smoothie', 0]]
# [['Americano', 0], ['CafeLatte', 0], ['Smoothie', 1]]
# 첫 글자: 2, 끝 글자: f
#
# ===== 개인 정보 =====
# 이름: SungHyeonPark
# 나이: 35
# 태어난 해: 1992
# ...
