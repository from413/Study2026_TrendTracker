# %% [markdown]
# # Gemini API 호출 프로젝트
#
# 이 노트북은 `google-genai` SDK를 사용하여 Gemini 모델을 호출하는 예제입니다.

# %%
from google import genai
import os
from dotenv import load_dotenv

# %%
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")
model_id = os.getenv("GOOGLE_MODEL", "gemini-2.0-flash-lite")

if not api_key:
    print("API 키가 설정되지 않았습니다. .env 파일을 확인해주세요.")
else:
    print(f"API 키 로드 완료. 사용할 모델: {model_id}")
# Out:
# API 키 로드 완료. 사용할 모델: gemini-2.5-flash

# %%
with open("prompt.md", "r", encoding="utf-8") as f:
    prompt_text = f.read()
print("테스트 프롬프트:")
print(prompt_text)
# Out:
# 테스트 프롬프트:
# 저녁 뭐 먹지? 냉장고에 돼지고기, 김치, 계란이 있어. 간단한 요리 레시피를 3가지 알려줘.

# %%
prompt_text = "바이브코딩의 세팅은 코딩의 제어흐름과 무엇이 다를까?"

# %%
client = genai.Client(api_key=api_key)
response = client.models.generate_content(
    model=model_id,
    contents=prompt_text
)
print("--- 응답 결과 ---")
print(response.text)
# Out:
# --- 응답 결과 ---
# 바이브코딩의 **세팅(Setup)**과 코딩의 **제어 흐름(Control Flow)**은 프로그래밍이라는 큰 틀 안에서 완전히 다른 차원의 개념입니다. 간단하게 비유하자면, 세팅은 '무대와 장비를 준비하는 과정'이고, 제어 흐름은 '무대 위에서 배우들이 대본에 따라 움직이는 방식'이라고 할 수 있습니다.
#
# 각각의 개념을 자세히 살펴보고 차이점을 비교해 봅시다.
#
# ---
#
# ### 1. 바이브코딩의 세팅 (Setup)
#
# *   **정의:** 바이브코딩 환경에서 코딩 작업을 시작하기 위해 필요한 **모든 준비 과정과 환경 설정**을 의미합니다. 이는 특정 프로젝트나 작업을 위한 개발 환경을 구축하는 것에 가깝습니다.
# *   **주요 활동:**
#     *   **개발 환경 구축:** IDE (통합 개발 환경) 설치 및 설정, 코드 편집기 선택 및 확장 기능 설치.
#     *   **언어 및 런타임 설정:** 특정 프로그래밍 언어(예: Python, JavaScript, Java)의 런타임 또는 SDK (Software Development Kit) 설치.
#     *   **종속성 관리:** 프로젝트에 필요한 라이브러리, 프레임워크, 모듈 등을 설치하고 설정하는 것 (예: `npm install`, `pip install`, `maven build`).
#     *   **프로젝트 초기화:** 새로운 프로젝트를 생성하고 기본적인 파일 구조(폴더, 설정 파일 등)를 설정하는 것.
#     *   **데이터베이스 연결 설정:** 데이터베이스를 사용하는 경우, 데이터베이스 서버 설정 및 연결 정보 구성.
#     *   **환경 변수 설정:** API 키, 비밀번호 등 민감한 정보나 환경에 따라 달라지는 값을 설정.
# *   **목적:** 코드를 작성하고 실행할 수 있는 **기반 환경**을 마련하여, 개발자가 온전히 비즈니스 로직 작성에 집중할 수 있도록 돕습니다.
#
# ### 2. 코딩의 제어 흐름 (Control Flow)
#
# *   **정의:** 작성된 코드 내부에서 **명령어들이 실행되는 논리적인 순서**를 의미합니다. 프로그램이 어떤 상황에서 어떤 코드를 실행하고, 어떤 코드를 건너뛰며, 어떤 코드를 반복할지 등을 결정하는 방식입니다.
# *   **주요 구성 요소:**
#     *   **순차적 실행 (Sequential Execution):** 코드가 위에서 아래로 한 줄씩 순서대로 실행되는 가장 기본적인 흐름.
#     *   **조건문 (Conditional Statements):** 특정 조건에 따라 다른 코드 블록을 실행하게 합니다. (예: `if/else`, `switch/case`)
#     *   **반복문 (Loop Statements):** 특정 코드 블록을 조건이 만족하는 동안 여러 번 반복해서 실행하게 합니다. (예: `for`, `while`, `do-while`)
#     *   **함수 호출 (Function Calls):** 프로그램의 특정 부분을 함수로 묶어 필요할 때마다 호출하여 실행 흐름을 해당 함수로 이동시켰다가 다시 돌아오게 합니다.
#     *   **예외 처리 (Exception Handling):** 프로그램 실행 중 발생하는 오류(예외)를 감지하고, 이에 대처하는 별도의 코드 블록을 실행합니다. (예: `try/catch/finally`)
#     *   **비동기 처리 (Asynchronous Operations):** 일부 작업이 완료될 때까지 기다리지 않고 다음 코드를 실행하며, 작업 완료 시점에 특정 코드를 실행하는 방식. (예: 콜백, Promise, async/await)
# *   **목적:** 프로그램이 주어진 입력에 따라 어떻게 동작하고, 어떤 결과를 만들어낼지 **내부적인 로직**을 정의하고 구현합니다.
#
# ---
#
# ### 주요 차이점 비교
#
# | 구분           | 바이브코딩의 세팅 (Setup)                                 | 코딩의 제어 흐름 (Control Flow)                                      |
# | :------------- | :-------------------------------------------------------- | :------------------------------------------------------------------- |
# | **목적**       | 코드를 작성하고 실행할 수 있는 **외부 환경 구축**       | 프로그램 **내부의 논리적 실행 순서** 정의 및 제어                 |
# | **수준**       | **프로젝트/시스템 레벨** (상위 레벨)                      | **코드/명령어 레벨** (하위 레벨)                                     |
# | **언제 발생?** | **코딩 시작 전** 또는 프로젝트 초기 단계, 환경 변경 시     | **프로그램 실행 중** 계속해서 발생                                   |
# | **무엇을 다룸?** | 도구, 라이브러리, 환경 변수, 파일 구조, 데이터베이스 연결 | `if`, `for`, `while`, 함수 호출, `try/catch` 등 프로그램 로직의 흐름 |
# | **누가 결정?** | 주로 **개발자**가 직접 구성하거나 도구의 도움을 받아 설정 | **개발자가 작성한 코드** 자체에 의해 결정                          |
# | **결과물**     | 설정된 개발 환경, `package.json`, `requirements.txt` 등 | 실제로 동작하는 프로그램의 기능과 로직                             |
#
# ---
#
# **결론적으로, 바이브코딩의 세팅은 코드를 "어디서 어떻게 쓸 준비를 할 것인가"에 대한 문제이고, 코딩의 제어 흐름은 "준비된 환경에서 코드가 어떻게 작동할 것인가"에 대한 문제라고 할 수 있습니다.**
#
# 둘은 완전히 다른 개념이지만, 효과적인 코딩을 위해서는 둘 다 중요합니다. 좋은 세팅은 개발 생산성을 높여주고, 잘 설계된 제어 흐름은 프로그램의 효율성과 안정성을 보장합니다.
